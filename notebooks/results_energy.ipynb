# %%
from pathlib import Path
import pandas as pd
import altair as alt

# %%
configs = {'LP-2fu-nofuse':'LP-NF-2', 'LP-2fu-fuse':'LP-F-2',
           'LP-1fu-nofuse':'LP-NF-1', 'LP-1fu-fuse':'LP-F-1',
           'HP-3fu-nofuse':'HP-NF-3', 'HP-3fu-fuse':'HP-F-3', 
           'HP-2fu-nofuse':'HP-NF-2', 'HP-2fu-fuse':'HP-F-2',
           'HP-1fu-nofuse':'HP-NF-1', 'HP-1fu-fuse':'HP-F-1',
#            'HP-3fu-fusepenalty':'HP-FP-3',
#            'HP-2fu-fusepenalty':'HP-FP-2',
#            'HP-1fu-fusepenalty':'HP-FP-1'
          }
configs
# Out:
# {'LP-2fu-nofuse': 'LP-NF-2',
#  'LP-2fu-fuse': 'LP-F-2',
#  'LP-1fu-nofuse': 'LP-NF-1',
#  'LP-1fu-fuse': 'LP-F-1',
#  'HP-3fu-nofuse': 'HP-NF-3',
#  'HP-3fu-fuse': 'HP-F-3',
#  'HP-2fu-nofuse': 'HP-NF-2',
#  'HP-2fu-fuse': 'HP-F-2',
#  'HP-1fu-nofuse': 'HP-NF-1',
#  'HP-1fu-fuse': 'HP-F-1'}

# %%
configs_ref = {'LP-NF-1':'LP-NF-2', 'LP-F-2':'LP-NF-2', 'LP-F-1':'LP-NF-2', 'HP-NF-2':'HP-NF-3', 'HP-NF-1':'HP-NF-3', 'HP-F-3':'HP-NF-3', 'HP-F-2':'HP-NF-3', 'HP-F-1':'HP-NF-3',
               'HP-FP-3':'HP-NF-3', 'HP-FP-2':'HP-NF-3', 'HP-FP-1':'HP-NF-3'}
configs_lp  = ['LP-NF-1', 'LP-F-2', 'LP-F-1']
configs_hp  = ['HP-NF-2', 'HP-NF-1', 'HP-F-3', 'HP-F-2', 'HP-F-1', 'HP-FP-3', 'HP-FP-2', 'HP-FP-1']

# %%
benchmarks = {
    'hmmer-small_0':'hmmer',
    #'libquantum-small_0':'libquantum',
    #'blackscholes_simsmall_1_0':'blackscholes',
    #'freqmine_simsmall_1_0':'freqmine',
    #'swaptions_simsmall_1_0':'swaptions',
    'integerNN_0':'integerNN',
    'streamvbyte_0':'streamvbyte',
    'img_cartoon_image1_0':'cartoon',
    'img_cartoon_image2_0':'cartoon',
    'img_cartoon_image3_0':'cartoon',
    'img_cartoon_image4_0':'cartoon',
    'img_cartoon_image5_0':'cartoon',
    'img_canny_image1_0':'canny',
    'img_canny_image2_0':'canny',
    'img_canny_image3_0':'canny',
    'img_canny_image4_0':'canny',
    'img_canny_image5_0':'canny',
    #'img_hist_image1_0':'hist',
    #'img_hist_image2_0':'hist',
    #'img_hist_image3_0':'hist',
    #'img_hist_image4_0':'hist',
    #'img_hist_image5_0':'hist',
    'img_integral_image1_0':'img_integral',
    'img_integral_image2_0':'img_integral',
    'img_integral_image3_0':'img_integral',
    'img_integral_image4_0':'img_integral',
    'img_integral_image5_0':'img_integral',
    'conv_image1_0':'conv',
    'conv_image2_0':'conv',
    'conv_image3_0':'conv',
    'conv_image4_0':'conv',
    'conv_image5_0':'conv',
    'img_erode_image1_0':'erode',
    'img_erode_image2_0':'erode',
    'img_erode_image3_0':'erode',
    'img_erode_image4_0':'erode',
    'img_erode_image5_0':'erode',
    'img_median_image1_0':'median',
    'img_median_image2_0':'median',
    'img_median_image3_0':'median',
    'img_median_image4_0':'median',
    'img_median_image5_0':'median',
    #'img_yuv444_image1_0':'img_yuv444',
    #'img_yuv444_image2_0':'img_yuv444',
    #'img_yuv444_image3_0':'img_yuv444',
    #'img_yuv444_image4_0':'img_yuv444',
    #'img_yuv444_image5_0':'img_yuv444',
    'amax_cols_normal_16bit_0_0':'amax',
    'amax_cols_normal_16bit_1_0':'amax',
    'amax_cols_normal_16bit_2_0':'amax',
    'amax_cols_normal_16bit_3_0':'amax',
    'amax_cols_normal_16bit_4_0':'amax',
    #'asum_cols_normal_16bit_0_0':'asum',
    #'asum_cols_normal_16bit_1_0':'asum',
    #'asum_cols_normal_16bit_2_0':'asum',
    #'asum_cols_normal_16bit_3_0':'asum',
    #'asum_cols_normal_16bit_4_0':'asum',
    #'gemv_normal_16bit_0_0':'gemv',
    #'gemv_normal_16bit_1_0':'gemv',
    #'gemv_normal_16bit_2_0':'gemv',
    #'gemv_normal_16bit_3_0':'gemv',
    #'gemv_normal_16bit_4_0':'gemv',
    #'ger_normal_16bit_0_0':'ger',
    #'ger_normal_16bit_1_0':'ger',
    #'ger_normal_16bit_2_0':'ger',
    #'ger_normal_16bit_3_0':'ger',
    #'ger_normal_16bit_4_0':'ger',
    'sqnrm2_cols_normal_16bit_0_0':'sqnrm2',
    'sqnrm2_cols_normal_16bit_1_0':'sqnrm2',
    'sqnrm2_cols_normal_16bit_2_0':'sqnrm2',
    'sqnrm2_cols_normal_16bit_3_0':'sqnrm2',
    'sqnrm2_cols_normal_16bit_4_0':'sqnrm2',
    'gemm_normal_16bit_0_0':'gemm',
    'gemm_normal_16bit_1_0':'gemm',
    'gemm_normal_16bit_2_0':'gemm',
    'gemm_normal_16bit_3_0':'gemm',
    'gemm_normal_16bit_4_0':'gemm',
    'fft_normal_8bit_0_0':'fft',
    'fft_normal_8bit_1_0':'fft',
    'fft_normal_8bit_2_0':'fft',
    'fft_normal_8bit_3_0':'fft',
    'fft_normal_8bit_4_0':'fft',
}

bench_order = ['hmmer', 'streamvbyte', 'integerNN', 'cartoon', 'sqnrm2', 'amax', 'gemm', 'fft', 'conv', 'median', 'img_integral', 'canny', 'erode']

# %%
component = 'fp/simd alu'

# %%
graph_names = {'Dynamic':'Normalized Dynamic Energy', 
               'Leakage':'Normalized Leakage Energy',
                 'Total':'Normalized Total Energy',
                  'Time':'Normalized Execution Time'}
graph_order = ['Normalized Dynamic Energy', 
               'Normalized Leakage Energy',
               'Normalized Total Energy',
               'Normalized Execution Time']

# %%
stats = Path('./stats/')
stats = stats.glob('**/roi.txt')
stats = list(stats)
stats = [p.parents[0] for p in stats]
#stats

# %%
df = []

for s in stats:
    bench  = s.name
    config = s.parents[1].name
    
    if bench in benchmarks.keys() and config in configs.keys():
        time  = pd.read_csv(s/'time.csv')
        try:
            time  = float(time['sim seconds'])
        except TypeError:
            continue

        mcpat = pd.read_csv(s/'power.csv')
        mcpat = mcpat[mcpat['Component'] == component]

        dynamic = float(mcpat['Runtime Dynamic [W]']) * time
        leakage = float(mcpat.loc[:, ['Gate Leakage [W]', 'Subthreshold Leakage [W]']].sum(axis='columns')) * time

        df.append({'Benchmark':bench, 'Config':config, 'Time':time, 'Dynamic':dynamic, 'Leakage':leakage, 'Total':dynamic+leakage})
        
df = pd.DataFrame(df)
df
# Out:
#                       Benchmark         Config      Time   Dynamic   Leakage  \
# 0                   integerNN_0    HP-1fu-fuse  0.017459  0.011926  0.005209
# 1                 streamvbyte_0    HP-1fu-fuse  0.308115  0.201683  0.091930
# 2    amax_cols_normal_16bit_0_0    HP-1fu-fuse  0.215933  0.169191  0.064426
# 3    amax_cols_normal_16bit_1_0    HP-1fu-fuse  0.207978  0.153998  0.062053
# 4    amax_cols_normal_16bit_2_0    HP-1fu-fuse  0.218046  0.170278  0.065056
# ..                          ...            ...       ...       ...       ...
# 516         img_median_image1_0  LP-2fu-nofuse  0.338089  0.657992  0.000254
# 517         img_median_image2_0  LP-2fu-nofuse  0.290952  0.566318  0.000219
# 518         img_median_image3_0  LP-2fu-nofuse  0.238989  0.465976  0.000179
# 519         img_median_image4_0  LP-2fu-nofuse  0.413957  0.808657  0.000311
# 520         img_median_image5_0  LP-2fu-nofuse  0.248554  0.485267  0.000187
#
#         Total
# 0    0.017135
# 1    0.293612
# 2    0.233617
# 3    0.216050
# 4    0.235334
# ..        ...
# 516  0.658246
# 517  0.566536
# 518  0.466155
# 519  0.808968
# 520  0.485454
#
# [521 rows x 6 columns]

# %%
df2 = df[df['Config'].isin(configs.keys()) & df['Benchmark'].isin(benchmarks.keys())].copy()
df2['Config'] = df2['Config'].replace(configs)
df2['Ref'] = df2['Config'].replace(configs_ref)
df2
# Out:
#                       Benchmark   Config      Time   Dynamic   Leakage  \
# 0                   integerNN_0   HP-F-1  0.017459  0.011926  0.005209
# 1                 streamvbyte_0   HP-F-1  0.308115  0.201683  0.091930
# 2    amax_cols_normal_16bit_0_0   HP-F-1  0.215933  0.169191  0.064426
# 3    amax_cols_normal_16bit_1_0   HP-F-1  0.207978  0.153998  0.062053
# 4    amax_cols_normal_16bit_2_0   HP-F-1  0.218046  0.170278  0.065056
# ..                          ...      ...       ...       ...       ...
# 516         img_median_image1_0  LP-NF-2  0.338089  0.657992  0.000254
# 517         img_median_image2_0  LP-NF-2  0.290952  0.566318  0.000219
# 518         img_median_image3_0  LP-NF-2  0.238989  0.465976  0.000179
# 519         img_median_image4_0  LP-NF-2  0.413957  0.808657  0.000311
# 520         img_median_image5_0  LP-NF-2  0.248554  0.485267  0.000187
#
#         Total      Ref
# 0    0.017135  HP-NF-3
# 1    0.293612  HP-NF-3
# 2    0.233617  HP-NF-3
# 3    0.216050  HP-NF-3
# 4    0.235334  HP-NF-3
# ..        ...      ...
# 516  0.658246  LP-NF-2
# 517  0.566536  LP-NF-2
# 518  0.466155  LP-NF-2
# 519  0.808968  LP-NF-2
# 520  0.485454  LP-NF-2
#
# [521 rows x 7 columns]

# %%
# match = {'HP-FP-3':'HP-F-3', 'HP-FP-2':'HP-F-2', 'HP-FP-1':'HP-F-1'}

# df_a = df[df['Config'].isin(configs.keys()) & df['Benchmark'].isin(benchmarks.keys())].copy()
# df_a['Config'] = df_a['Config'].replace(configs)
# df_a['Orig'] = df_a['Config'].replace(match)
# df_a = df_a.merge(df_a, left_on=['Benchmark', 'Orig'], right_on=['Benchmark', 'Config'], suffixes=('', ' orig'))
# df_a = df_a[df_a['Config'].isin(match.keys())]
# df_a = df_a.drop(columns=['Orig orig'])

# df_a['Slow down'] = df_a['Time'] / df_a['Time orig']
# df_a['Slow down'].mean()

# %%
df3 = df2.merge(df2, left_on=['Benchmark', 'Ref'], right_on=['Benchmark', 'Config'], suffixes=('', ' ref')).copy()
df3['Time'] = df3['Time'] / df3['Time ref']
df3['Dynamic'] = df3['Dynamic'] / df3['Dynamic ref']
df3['Leakage'] = df3['Leakage'] / df3['Leakage ref']
df3['Total'] = df3['Total'] / df3['Total ref']
df3 = df3.drop(columns=['Ref', 'Config ref', 'Time ref', 'Dynamic ref', 'Leakage ref', 'Total ref', 'Ref ref'])
df3
# Out:
#                         Benchmark   Config      Time   Dynamic   Leakage  \
# 0                     integerNN_0   HP-F-1  1.000630  0.803254  0.333543
# 1                     integerNN_0  HP-NF-1  1.045679  1.017399  0.348559
# 2                     integerNN_0   HP-F-2  1.000000  0.818390  0.666666
# 3                     integerNN_0  HP-NF-2  1.000688  1.000268  0.667124
# 4                     integerNN_0   HP-F-3  1.000000  0.820271  1.000000
# ..                            ...      ...       ...       ...       ...
# 516  sqnrm2_cols_normal_16bit_3_0  LP-NF-2  1.000000  1.000000  1.000000
# 517  sqnrm2_cols_normal_16bit_4_0   LP-F-1  1.001048  0.982470  0.500523
# 518  sqnrm2_cols_normal_16bit_4_0  LP-NF-1  1.001029  1.000591  0.500514
# 519  sqnrm2_cols_normal_16bit_4_0   LP-F-2  1.000000  0.998062  1.000000
# 520  sqnrm2_cols_normal_16bit_4_0  LP-NF-2  1.000000  1.000000  1.000000
#
#         Total
# 0    0.562460
# 1    0.674522
# 2    0.740609
# 3    0.829484
# 4    0.912408
# ..        ...
# 516  1.000000
# 517  0.981831
# 518  0.999928
# 519  0.998065
# 520  1.000000
#
# [521 rows x 6 columns]

# %%
df4 = df3.set_index(['Config', 'Benchmark'])
df4 = df4.groupby(by=[None, benchmarks], level=['Config', 'Benchmark']).mean()
df4
# Out:
#                           Time   Dynamic   Leakage     Total
# Config  Benchmark
# HP-F-1  amax          1.000161  0.875550  0.333387  0.602104
#         canny         1.090265  0.890065  0.363421  0.650170
#         cartoon       1.085873  0.902494  0.361957  0.655569
#         conv          1.183453  0.851283  0.394484  0.694535
#         erode         1.782578  0.920439  0.594192  0.837244
# ...                        ...       ...       ...       ...
# LP-NF-2 img_integral  1.000000  1.000000  1.000000  1.000000
#         integerNN     1.000000  1.000000  1.000000  1.000000
#         median        1.000000  1.000000  1.000000  1.000000
#         sqnrm2        1.000000  1.000000  1.000000  1.000000
#         streamvbyte   1.000000  1.000000  1.000000  1.000000
#
# [121 rows x 4 columns]

# %%
# conf = ['HP-NF-3', 'HP-NF-2', 'HP-NF-1', 'HP-FP-3', 'HP-FP-2', 'HP-FP-1']
# bench = 'conv'
# df_b = df4.loc[(conf, bench), ['Time', 'Total']]
# df_b['Save'] = 100 * (1 - df_b['Total'])
# df_b

# %%
def bar_plot(df, configs_order, spx=alt.Undefined):
    chart = alt.Chart(df).mark_bar(size=18).encode(
        y=alt.Y(
            'Config:N',
            sort=configs_order,
            title=""
        ),
        x=alt.X(
            'Value:Q',
            axis=alt.Axis(orient='top'),
            title=""
        ),
        column=alt.Column(
            'Var:N',
            sort=graph_order,
            title=""
        ),
        row=alt.Row(
            'Benchmark:N',
            sort=bench_order,
            spacing=spx
        ),
        color=alt.Color(
            'Config:N',
            sort=configs_order,
            scale=alt.Scale(scheme='yellowgreenblue')
        )
    ).properties(
        width=300,
        height=alt.Step(22)
    )
    
    return chart

# %%
df_hp = df4.copy().reset_index()
df_hp = df_hp[df_hp['Config'].isin(configs_hp)]
df_hp = pd.melt(df_hp, id_vars=['Config', 'Benchmark'], var_name='Var', value_name='Value')
df_hp['Var'] = df_hp['Var'].replace(graph_names)
df_hp
# Out:
#       Config     Benchmark                        Var     Value
# 0     HP-F-1          amax  Normalized Execution Time  1.000161
# 1     HP-F-1         canny  Normalized Execution Time  1.090265
# 2     HP-F-1       cartoon  Normalized Execution Time  1.085873
# 3     HP-F-1          conv  Normalized Execution Time  1.183453
# 4     HP-F-1         erode  Normalized Execution Time  1.782578
# ..       ...           ...                        ...       ...
# 235  HP-NF-2  img_integral    Normalized Total Energy  0.822827
# 236  HP-NF-2     integerNN    Normalized Total Energy  0.829484
# 237  HP-NF-2        median    Normalized Total Energy  1.022878
# 238  HP-NF-2        sqnrm2    Normalized Total Energy  0.802747
# 239  HP-NF-2   streamvbyte    Normalized Total Energy  0.817154
#
# [240 rows x 4 columns]

# %%
hp_energy = bar_plot(df_hp[~(df_hp['Var'] == 'Normalized Execution Time')], configs_hp)
hp_time = bar_plot(df_hp[df_hp['Var'] == 'Normalized Execution Time'], configs_hp)
hp_chart = alt.concat(hp_energy, hp_time).configure_axis(
    labelFontSize=16, titleFontSize=16,
).configure_header(
    labelFontSize=18, titleFontSize=18
).configure_legend(
    titleFontSize=18, labelFontSize=18, orient='top'
)
hp_chart

# %%
hp_chart.save('plots/hp_energy_time.svg', webdriver='firefox')

# %%
df_lp = df4.copy().reset_index()
df_lp = df_lp[df_lp['Config'].isin(configs_lp)]
df_lp = pd.melt(df_lp, id_vars=['Config', 'Benchmark'], var_name='Var', value_name='Value')
df_lp['Var'] = df_lp['Var'].replace(graph_names)
df_lp

# %%
lp_energy = bar_plot(df_lp[~(df_lp['Var'] == 'Normalized Execution Time')], configs_lp, spx=30)
lp_time = bar_plot(df_lp[df_lp['Var'] == 'Normalized Execution Time'], configs_lp, spx=30)
lp_chart = alt.concat(lp_energy, lp_time).configure_axis(
    labelFontSize=16, titleFontSize=16
).configure_header(
    labelFontSize=17, titleFontSize=18
).configure_legend(
    titleFontSize=18, labelFontSize=18, orient='top'
)
lp_chart
# Out:
# alt.ConcatChart(...)

# %%
lp_chart.save('plots/lp_energy_time.svg', webdriver='firefox')
